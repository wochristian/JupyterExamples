# %% [markdown]
# <!--NAVIGATION-->
# < [Contents](../index.ipynb) | [Inquiry](inquiry.ipynb) >

# %% [markdown]
# Predict Molecular Dynamics (Instructor Key)
# ===========================

# %% [markdown]
# ![image.png](attachment:image.png)
# Predict the free expansion of a gas.

# %% [markdown]
# ###### Worksheet: [English](sim_predict_en.pdf)  or [Hebrew](sim_predict_he.pdf)

# %% [markdown]
# Describe and explain the time development of a hard-sphere gas under different conditions.  A picture of the initial state of the system is given in the upper left cell of each table; the black arrows represent the velocities of the particles.
#
# 1. Gas without collisions, directed velocity
# Initial positions – The particles are randomly scattered in the left half of the container. Initial velocities – all the particles have equal velocities: fixed magnitude and upward direction. Collisions – no collisions, the particles pass through each other.
#
# 2.	Gas with collisions, directed velocities
# Initial positions – The particles are randomly scattered in the left half of the container.  Initial velocities – all the particles have equal velocities: fixed magnitude and upward direction.  Collisions – The particles collide with each other with a fixed force.
#
# 3.	Gas with no collisions, random velocities.
# Initial positions – The particles are randomly scattered in the left half of the container.  Initial velocities – the particles’ velocities are random (magnitude and direction).  Collisions – no collisions, the particles pass through each other.

# %% [markdown]
# <!--NAVIGATION-->
# < [Contents](../index.ipynb) | [Inquiry](inquiry.ipynb) >
