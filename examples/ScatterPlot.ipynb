# %%
# %matplotlib inline
# %matplotlib notebook
# Test of scatter plot animation

import numpy as np
import matplotlib.pyplot as plt
from vpython import *

px = np.random.rand(100)
py = np.random.rand(100)
plt.figure(figsize=(6, 6))
plt.scatter(px, py, s=50)
plt.axis('equal')
# plt.xlim(0, 1)
# plt.ylim(0, 1)
# plt.axis('off')
plt.show()

t=0;
while t < 100:
    vpython.rate(100)
    px = np.random.rand(100)
    py = np.random.rand(100)
    t=t+1
    plt.scatter(px, py, s=50)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
